# %%
from openbb import obb
import pandas as pd

obb.user.preferences.output_type = 'dataframe'
df = obb.equity.price.historical('AAPL', start_date='1997-05-05', provider='yfinance')
# print(df.head(5))
# print(df.tail(5))
# print(df.describe())

columns = ['open', 'high', 'low', 'close', 'volume', 'split_ratio', 'dividends']
df.columns = columns
# print(df[['close']])
print(df[0:3])
# print(df.values)
df.index = pd.to_datetime(df.index)
print(df['2020-01-01': '2020-01-31'])
df.loc[df.index[0]]
# Out:
#                 open      high       low     close     volume  split_ratio  \
# date
# 1997-05-05  0.151786  0.152902  0.149554  0.151786   98492800          0.0
# 1997-05-06  0.151786  0.152902  0.149554  0.150670   83148800          0.0
# 1997-05-07  0.150670  0.151786  0.146205  0.147321  114217600          0.0
#
#             dividends
# date
# 1997-05-05        0.0
# 1997-05-06        0.0
# 1997-05-07        0.0
#                  open       high        low      close     volume  \
# date
# 2020-01-02  74.059998  75.150002  73.797501  75.087502  135480400
# 2020-01-03  74.287498  75.144997  74.125000  74.357498  146322800
# 2020-01-06  73.447502  74.989998  73.187500  74.949997  118387200
# 2020-01-07  74.959999  75.224998  74.370003  74.597504  108872000
# 2020-01-08  74.290001  76.110001  74.290001  75.797501  132079200
# 2020-01-09  76.809998  77.607498  76.550003  77.407501  170108400
# 2020-01-10  77.650002  78.167503  77.062500  77.582497  140644800
# ...
